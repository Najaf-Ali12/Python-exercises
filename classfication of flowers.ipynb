# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,MinMaxScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,f1_score

# %%
#load the dataset
data=pd.read_csv("datasets to work with/iris.csv")
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#deciding features and output
X=data.drop("species",axis=1)
y=data["species"]
y.head()
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
#train test split
X_train,X_test,y_train,y_test=train_test_split(X,y, train_size=0.8, test_size=0.2)

# %%
#calling the model
model=LogisticRegression()

# %%
#Train the model
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#predict the model
y_pred=model.predict(X_test)

# %%
#evaluating the model
print("classification report is \n",classification_report(y_test,y_pred))
print("The confusion matrix is \n", confusion_matrix(y_test,y_pred))
# Out:
# classification report is
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      0.90      0.95        10
#    virginica       0.91      1.00      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
#
# The confusion matrix is
#  [[10  0  0]
#  [ 0  9  1]
#  [ 0  0 10]]

# %%
# Out:
# E:\vs code software\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 y_pred=model.predict([[5.1,3.5,1.4,0.2]])
# ----> 2 print(f1_score(y_pred,["set"]))
#
# File E:\vs code software\python\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File E:\vs code software\python\Lib\site-packages\sklearn\metrics\_classification.py:1279, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1099 @validate_params(
#    1100     {
#    1101         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1126     zero_division="warn",
#    1127 ):
#    1128     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1129
#    1130     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1277     array([0.66666667, 1.        , 0.66666667])
#    1278     """
# -> 1279     return fbeta_score(
#    1280         y_true,
#    1281         y_pred,
#    1282         beta=1,
#    1283         labels=labels,
#    1284         pos_label=pos_label,
#    1285         average=average,
#    1286         sample_weight=sample_weight,
#    1287         zero_division=zero_division,
#    1288     )
#
# File E:\vs code software\python\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File E:\vs code software\python\Lib\site-packages\sklearn\metrics\_classification.py:1471, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1291 @validate_params(
#    1292     {
#    1293         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1320     zero_division="warn",
#    1321 ):
#    1322     """Compute the F-beta score.
#    1323
#    1324     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1468     0.12...
#    1469     """
# -> 1471     _, _, f, _ = precision_recall_fscore_support(
#    1472         y_true,
#    1473         y_pred,
#    1474         beta=beta,
#    1475         labels=labels,
#    1476         pos_label=pos_label,
#    1477         average=average,
#    1478         warn_for=("f-score",),
#    1479         sample_weight=sample_weight,
#    1480         zero_division=zero_division,
#    1481     )
#    1482     return f
#
# File E:\vs code software\python\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File E:\vs code software\python\Lib\site-packages\sklearn\metrics\_classification.py:1775, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1612 """Compute precision, recall, F-measure and support for each class.
#    1613
#    1614 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1772  array([2, 2, 2]))
#    1773 """
#    1774 _check_zero_division(zero_division)
# -> 1775 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1777 # Calculate tp_sum, pred_sum, true_sum ###
#    1778 samplewise = average == "samples"
#
# File E:\vs code software\python\Lib\site-packages\sklearn\metrics\_classification.py:1555, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1553     if pos_label not in present_labels:
#    1554         if len(present_labels) >= 2:
# -> 1555             raise ValueError(
#    1556                 f"pos_label={pos_label} is not a valid label. It "
#    1557                 f"should be one of {present_labels}"
#    1558             )
#    1559     labels = [pos_label]
#    1560 else:
#
# ValueError: pos_label=1 is not a valid label. It should be one of ['set', 'setosa']
